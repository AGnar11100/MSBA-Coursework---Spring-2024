# %% [markdown]
# # Web Scraping Lecture Part 2
#
# ## Content
# 5. Interacting with JSON APIs
# 6. Interacting with other type of APIs
# 7. Preparing for Project : Job Data Scraping

# %% [markdown]
# # 5. Interacting with JSON API
#
#
# ## What is API?
#
# API stands for “Application Programming Interface.” It is an interface or communication protocol between a client and a server intended to simplify the building of client-side software. It has been described as a “contract” between the client and the server, such that if the client makes a request in a specific format, it will always get a response in a specific format or initiate a defined action. An API may be for a web-based system, operating system, database system, computer hardware, or software library.(Wiki)
#
# Many websites have public APIs providing data feeds via JSON or some other formats.
#
# ## JSON Data Introduction
#
# JSON short for JavaScript Object Notation, has become one of the standard formats for sending data by HTTP request between web browers and other applications. It is a much more free-form data format than a tabular text form like CSV.
#
# For exmaple, this website shows the last 30 GitHub issues for pandas, https://api.github.com/repos/pandas-dev/pandas/issues. We call it is an API, and the data format is in JSON. Most web APIs return to JSON or xml format.
#
# Another example of JSON:
#
#     {"ticker":"AAPL:US","return_code":0,"ttl":300,"disp_name":"Apple Inc","last_price":222.11,"price_precision":3.0,"time_of_last_updt":"2018-10-12","pct_chge_1D":3.57192993}
#
# It is a much more free-form data format than a tabular text form like CSV.
#
# Sometimes people see json as nested dictionary in python.
#
# **json library**
#
# There are several python libraries for reading and writing JSON data. *json* is one of those. To convert a JSON string to Python form, we use *json.loads*.

# %%
#Define a json string. 
obj="""
{"name":"Wes",
 "places_lived":["United States","Spain","China"],
 "siblings":[{"name":"Scott","age":30,"pets":["Zeus","Zuko"]},
             {"name":"Katie","age":38,"pets":["Sixes","Cisco"]}]
}
"""
obj
# Out:
# '\n{"name":"Wes",\n "places_lived":["United States","Spain","China"],\n "siblings":[{"name":"Scott","age":30,"pets":["Zeus","Zuko"]},\n             {"name":"Katie","age":38,"pets":["Sixes","Cisco"]}]\n}\n'

# %%
import json
result=json.loads(obj) # json.loads() convert a json string to python dictionary.
result
#result can be treated as a dictionary in python.
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'China'],
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Cisco']}]}

# %% [markdown]
# <font color='red'>Exercise:</font>
# Can we convert result (as it is already a dictionary) into dataframe?

# %%
# The answer is no because the dictionary needs to have same length in the value of each elements

# %%
result['siblings']
# Out:
# [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#  {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Cisco']}]

# %%
result['siblings'][0]
# Out:
# {'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']}

# %%
result['siblings'][0]['pets']
# Out:
# ['Zeus', 'Zuko']

# %%
result['siblings'][0]['pets'][0]
# Out:
# 'Zeus'

# %%
#converts a python object back to JSON string. 
asjon=json.dumps(result)
asjon
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "China"], "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Cisco"]}]}'

# %%
import pandas as pd
siblings=pd.DataFrame(result['places_lived'])
siblings
# Out:
#                0
# 0  United States
# 1          Spain
# 2          China

# %%
import pandas as pd
siblings=pd.DataFrame(result["siblings"])
siblings
# Out:
#     name  age            pets
# 0  Scott   30    [Zeus, Zuko]
# 1  Katie   38  [Sixes, Cisco]

# %%
import pandas as pd
siblings=pd.DataFrame(result["siblings"][0])
siblings
# Out:
#     name  age  pets
# 0  Scott   30  Zeus
# 1  Scott   30  Zuko

# %%
import pandas as pd
siblings=pd.DataFrame(result["siblings"][0]['pets'])
siblings
# Out:
#       0
# 0  Zeus
# 1  Zuko

# %% [markdown]
# ## <font color='red'>**Exercise: Access the nested key ‘salary’ from the following JSON**</font>
#
# write code to print the value of salary
#
# expected output:
#
# 7000

# %%
import json

sampleJson = """{ 
   "company":{ 
      "employee":{ 
         "name":"emma",
         "payble":{ 
            "salary":7000,
            "bonus":800
         }
      }
   }
}"""

data = json.loads(sampleJson)
print(data['company']['employee']['payble']['salary'])
# Out:
# 7000

# %% [markdown]
# ## <font color='red'>**Exercise:**</font>
# Parse the following JSON to get all the values of a key ‘name’ within an array
#
# Expected output:
#
# ["name1", "name2"]

# %%
import json

sampleJson = """[ 
   { 
      "id":1,
      "name":"name1",
      "color":[ 
         "red",
         "green"
      ]
   },
   { 
      "id":2,
      "name":"name2",
      "color":[ 
         "pink",
         "yellow"
      ]
   }
]"""

data = []
data = json.loads(sampleJson)
dataList = [item.get('name') for item in data]
print(dataList)
# Out:
# ['name1', 'name2']

# %% [markdown]
# ## Scraping JSON using requests lib
# One easy-to-use method to access APIs from python is the **requests** package. The requests library will make a **GET** request to a web server, which will download the HTML contents of a given web page for us. There are several different types of requests we can make using requests, of which GET is just one.
#
# To find the last 30 GitHub issues for pandas on GitHub, we make a **GET HTTP** request.

# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)#When you ping a website or portal for information this is called making a request. 
                       #That is exactly what the Requests library has been designed to do.
resp # resp is a Response object.
# Out:
# <Response [200]>

# %% [markdown]
# After running our request, we get a Response object. This object has a status_code property, which indicates if the page was downloaded successfully.
#
# A status_code of 200 means that the page downloaded successfully. We won’t fully dive into status codes here, but a status code starting with a 2 generally indicates success, and a code starting with a 4 or a 5 indicates an error.

# %%
data=resp.json()# Response object's json method will return to a dictionary 
                # containing JSON parsed into native python objects. 
len(data)
# each element in data is a dictionary containing all the data found on a GitHub issue page.
# Out:
# 30

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52430',
#   'id': 1654728051,
#   'node_id': 'PR_kwDOAA0YD85NoUjI',
#   'number': 52430,
#   'title': 'PERF: Series.to_numpy with float dtype and na_value=np.nan',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-05T00:03:05Z',
#   'updated_at': '2023-04-05T01:39:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52430',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52430',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52430.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52430.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.1.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nAvoids filling na values with `np.nan` if the array is already a numpy float dtype. (`DataFrame` has a similar optimization in `BlockManager.as_array`)\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\nser = pd.Series(np.random.randn(10_000_000))\r\n\r\n%timeit ser.to_numpy(dtype="float64", na_value=np.nan, copy=False)\r\n\r\n# 22.5 ms ± 2.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)          -> main\r\n# 1.97 µs ± 24.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)   -> PR\r\n```\r\n\r\n\r\n\r\n\r\n\r\nASV added:\r\n```\r\n       before           after         ratio\r\n     [3ce07cb4]       [020fb14a]\r\n     <main>           <series-to-numpy-float-nan>\r\n-     1.02±0.02ms      2.12±0.03μs     0.00  series_methods.ToNumpy.time_to_numpy_float_with_nan\r\n\r\nSOME BENCHMARKS HAVE CHANGED SIGNIFICANTLY.\r\nPERFORMANCE INCREASED.\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52429',
#   'id': 1654692124,
#   'node_id': 'I_kwDOAA0YD85ioJkc',
#   'number': 52429,
#   'title': 'API/DEPR: dtype=(str|bytes) interpret as pyarrow',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T23:08:12Z',
#   'updated_at': '2023-04-04T23:08:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "In 2.0 we made a lot of progress in ensuring passing dtype=foo or .astype(foo) actually returned the requested dtype rather than silently giving something else.  bytes and str are the main remaining cases where we silently do something else (cast to object, but not as consistently as intended).  \r\n\r\nInstead, let's interpret `dtype=str` as `string[pyarrow]` and `dtype=bytes` as `bytes[pyarrow]` (with a deprecation cycle, and once we require pyarrow)\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52428',
#   'id': 1654686974,
#   'node_id': 'PR_kwDOAA0YD85NoMHG',
#   'number': 52428,
#   'title': 'REF: define reductions non-dynamically',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T23:02:26Z',
#   'updated_at': '2023-04-04T23:02:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52428',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52428',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52428.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52428.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52427',
#   'id': 1654660259,
#   'node_id': 'I_kwDOAA0YD85ioByj',
#   'number': 52427,
#   'title': 'BUG: describe with double[pyarrow] does not return pyarrow backed series.',
#   'user': {'login': 'rohanjain101',
#    'id': 38412262,
#    'node_id': 'MDQ6VXNlcjM4NDEyMjYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38412262?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rohanjain101',
#    'html_url': 'https://github.com/rohanjain101',
#    'followers_url': 'https://api.github.com/users/rohanjain101/followers',
#    'following_url': 'https://api.github.com/users/rohanjain101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rohanjain101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rohanjain101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rohanjain101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rohanjain101/orgs',
#    'repos_url': 'https://api.github.com/users/rohanjain101/repos',
#    'events_url': 'https://api.github.com/users/rohanjain101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rohanjain101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T22:27:36Z',
#   'updated_at': '2023-04-04T22:27:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> a = pd.Series([100.0, 200.0], dtype=pd.ArrowDtype(pa.float64()))\r\n>>> b = a.describe()\r\n>>> b.dtype\r\nFloat64Dtype()\r\n>>>\n```\n\n\n### Issue Description\n\nDescribe with arrow backend returns an extension array datatype instead of pyarrow datatype.\n\n### Expected Behavior\n\nI expect the returned series to be of dtype double[pyarrow].\n\n### Installed Versions\n\n<details>\r\n\r\n>>> pd.show_versions()\r\nC:\\pandas2_ps_04323\\lib\\site-packages\\_distutils_hack\\__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 478d340667831908b5b4bf09a2787a11a14560c9\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 85 Stepping 7, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 2.0.0\r\nnumpy            : 1.24.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.5.1\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : 7.0.1\r\nhypothesis       : None\r\nsphinx           : 4.2.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.12.0\r\npandas_datareader: None\r\nbs4              : 4.12.0\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52426',
#   'id': 1654652813,
#   'node_id': 'PR_kwDOAA0YD85NoEzW',
#   'number': 52426,
#   'title': 'API: Series/DataFrame from empty dict should have RangeIndex',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T22:18:16Z',
#   'updated_at': '2023-04-04T23:55:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52426',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52426',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52426.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52426.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52404\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52425',
#   'id': 1654578250,
#   'node_id': 'I_kwDOAA0YD85intxK',
#   'number': 52425,
#   'title': 'BUG: to_datetime crashes with float32[pyarrow] dtype',
#   'user': {'login': 'rohanjain101',
#    'id': 38412262,
#    'node_id': 'MDQ6VXNlcjM4NDEyMjYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38412262?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rohanjain101',
#    'html_url': 'https://github.com/rohanjain101',
#    'followers_url': 'https://api.github.com/users/rohanjain101/followers',
#    'following_url': 'https://api.github.com/users/rohanjain101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rohanjain101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rohanjain101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rohanjain101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rohanjain101/orgs',
#    'repos_url': 'https://api.github.com/users/rohanjain101/repos',
#    'events_url': 'https://api.github.com/users/rohanjain101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rohanjain101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-04-04T21:06:26Z',
#   'updated_at': '2023-04-04T22:14:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> a = pd.Series([10.2, 100.2], dtype=pd.ArrowDtype(pa.float32()))\r\n>>> pd.to_datetime(a)\r\nFatal Python error: Cannot recover from stack overflow.\r\nPython runtime state: initialized\r\n\r\nCurrent thread 0x00008998 (most recent call first):\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\arrow\\dtype.py", line 155 in name\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\arrow\\dtype.py", line 98 in __repr__\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\dtypes\\common.py", line 594 in is_dtype_equal\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 572 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", li ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52424',
#   'id': 1654568329,
#   'node_id': 'PR_kwDOAA0YD85NnySf',
#   'number': 52424,
#   'title': 'PERF: avoid is_dtype_equal',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:57:36Z',
#   'updated_at': '2023-04-04T20:57:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52424',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52424',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52424.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52424.patch',
#    'merged_at': None},
#   'body': 'This gets rid of all our non-test usages.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52423',
#   'id': 1654566616,
#   'node_id': 'PR_kwDOAA0YD85Nnx6x',
#   'number': 52423,
#   'title': 'TYP/TST: tests/mypy complaints failing locally',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:56:00Z',
#   'updated_at': '2023-04-04T20:56:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52423',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52423',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52423.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52423.patch',
#    'merged_at': None},
#   'body': 'This un-xfails-on-mac a test that is passing locally.  Also suppresses some mypy complaints.  I\'m still seeing a complaint\r\n\r\n```\r\npandas/io/formats/printing.py:266: error: Incompatible types in assignment (expression has type "Tuple[Type[Dict[Any, Any]]]", base class "BaseFormatter" defined the type as "Type[str]")  [assignment]\r\n```\r\n\r\nthat I haven\'t found a solution for',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52422',
#   'id': 1654532704,
#   'node_id': 'PR_kwDOAA0YD85Nnql6',
#   'number': 52422,
#   'title': 'BUG: merge with arrow and numpy dtypes raises',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/104',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104/labels',
#    'id': 9238212,
#    'node_id': 'MI_kwDOAA0YD84AjPbE',
#    'number': 104,
#    'title': '2.0.1',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 10,
#    'closed_issues': 12,
#    'state': 'open',
#    'created_at': '2023-04-03T07:21:10Z',
#    'updated_at': '2023-04-04T20:26:42Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-04T20:26:42Z',
#   'updated_at': '2023-04-04T21:00:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52422',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52422',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52422.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52422.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52406 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis is similar to what we did for the Indexing engine',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52421',
#   'id': 1654528623,
#   'node_id': 'PR_kwDOAA0YD85Nnps3',
#   'number': 52421,
#   'title': 'PERF: lazify IO imports',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:23:09Z',
#   'updated_at': '2023-04-04T23:43:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52421',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52421',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52421.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52421.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52420',
#   'id': 1654487715,
#   'node_id': 'PR_kwDOAA0YD85Nngoh',
#   'number': 52420,
#   'title': 'DEPR: allowing non-class returns for _constructor etc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T19:54:33Z',
#   'updated_at': '2023-04-04T20:59:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52420',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52420',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52420.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52420.patch',
#    'merged_at': None},
#   'body': "- [x] closes #51772 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nI'd be OK with leaving out the `__init_subclass__` bit and just have this be in the docs.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52419',
#   'id': 1654449597,
#   'node_id': 'PR_kwDOAA0YD85NnYoB',
#   'number': 52419,
#   'title': 'DEPR: accepting Manager objects in DataFrame/Series',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T19:23:56Z',
#   'updated_at': '2023-04-04T22:16:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52419',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52419',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52419.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52419.patch',
#    'merged_at': None},
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52391/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52391/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52388',
#   'id': 1652907461,
#   'node_id': 'I_kwDOAA0YD85ihV3F',
#   'number': 52388,
#   'title': 'BUG: `ArrowTemporalProperties` object has no attribute `day_name`',
#   'user': {'login': 'matteosantama',
#    'id': 13473688,
#    'node_id': 'MDQ6VXNlcjEzNDczNjg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13473688?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matteosantama',
#    'html_url': 'https://github.com/matteosantama',
#    'followers_url': 'https://api.github.com/users/matteosantama/followers',
#    'following_url': 'https://api.github.com/users/matteosantama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/matteosantama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/matteosantama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/matteosantama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/matteosantama/orgs',
#    'repos_url': 'https://api.github.com/users/matteosantama/repos',
#    'events_url': 'https://api.github.com/users/matteosantama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/matteosantama/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 685114413,
#     'node_id': 'MDU6TGFiZWw2ODUxMTQ0MTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet',
#     'name': 'IO Parquet',
#     'color': '5319e7',
#     'default': False,
#     'description': 'parquet, feather'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-03T23:23:59Z',
#   'updated_at': '2023-04-04T13:34:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nFor a parquet dataset with a datetime column "Expiration", this works\r\n\r\n```python\r\npd.read_parquet("spx.parquet", dtype_backend="numpy_nullable")["Expiration"].dt.day_name()\r\n```\r\n\r\nand this doesn\'t\r\n\r\n```python\r\npd.read_parquet("spx.parquet", dtype_backend="pyarrow")["Expiration"].dt.day_name()\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nWhen reading the parquet file with `dtype_backend="pyarrow"`, the `.dt` accessor does not exist on the column "Expiration".\r\n\r\nThe dtype is\r\n\r\n```python\r\n>>> spx["Expiration"].dtype\r\n# timestamp[us][pyarrow]\r\n```\r\n\r\n### Expected Behavior\r\n\r\nThe `.dt` accessor should be accessible regardless of which data backend is used.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 478d340667831908b5b4bf09a2787a11a14560c9\r\npython           : 3.11.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.2.0\r\nVersion          : Darwin Kernel Version 22.2.0: Fri Nov 11 02:03:51 PST 2022; root:xnu-8792.61.2~4/RELEASE_ARM64_T6000\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.0\r\nnumpy            : 1.24.2\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.0\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.11.0\r\npandas_datareader: None\r\nbs4              : 4.11.2\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.7.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52386',
#   'id': 1652833045,
#   'node_id': 'I_kwDOAA0YD85ihDsV',
#   'number': 52386,
#   'title': 'BUG: Values in `DataTimeProperties.days` overflowing due to `int32` restriction in `pandas-2.0`',
#   'user': {'login': 'galipremsagar',
#    'id': 11664259,
#    'node_id': 'MDQ6VXNlcjExNjY0MjU5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11664259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galipremsagar',
#    'html_url': 'https://github.com/galipremsagar',
#    'followers_url': 'https://api.github.com/users/galipremsagar/followers',
#    'following_url': 'https://api.github.com/users/galipremsagar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/galipremsagar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/galipremsagar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/galipremsagar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/galipremsagar/orgs',
#    'repos_url': 'https://api.github.com/users/galipremsagar/repos',
#    'events_url': 'https://api.github.com/users/galipremsagar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/galipremsagar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/104',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104/labels',
#    'id': 9238212,
#    'node_id': 'MI_kwDOAA0YD84AjPbE',
#    'number': 104,
#    'title': '2.0.1',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 10,
#    'closed_issues': 12,
#    'state': 'open',
#    'created_at': '2023-04-03T07:21:10Z',
#    'updated_at': '2023-04-04T20:26:42Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2023-04-03T22:00:57Z',
#   'updated_at': '2023-04-03T22:52:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n(Pdb) data\r\n[136457654736252, 134736784364431, 245345345545332, 223432411, 2343241, 3634548734, 23234]\r\n(Pdb) dtype\r\n'timedelta64[s]'\r\n(Pdb) np.array(data, dtype=dtype)\r\narray([136457654736252, 134736784364431, 245345345545332,       223432411,\r\n               2343241,      3634548734,           23234],\r\n      dtype='timedelta64[s]')\r\n(Pdb) pd.Series(np.array(data, dtype=dtype))\r\n0   1579371003 days 21:24:12\r\n1   1559453522 days 17:40:31\r\n2   2839645203 days 01:42:12\r\n3         2586 days 00:33:31\r\n4           27 days 02:54:01\r\n5        42066 days 12:52:14\r\n6            0 days 06:27:14\r\ndtype: timedelta64[s]\r\n(Pdb) psr = pd.Series(np.array(data, dtype=dtype))\r\n(Pdb) psr.dt.days\r\n0    1579371003\r\n1    1559453522\r\n2   -1455322093       # Overflowing because of `int32` output dtype.\r\n3          2586\r\n4            27\r\n5         42066\r\n6             0\r\ndtype: int32\r\n(Pdb) pd.Series([1579371003, 1559453522, 1455322093, 2839645203])\r\n0    1579371003\r\n1    1559453522\r\n2    1455322093\r\n3    2839645203      # This value can be fit in `int64` dtype easily.\r\ndtype: int64\r\n(Pdb) pd.Series([1579371003, 1559453522, 1455322093, 2839645203]).astype('int32')\r\n0    1579371003\r\n1    1559453522\r\n2    1455322093\r\n3   -1455322093\r\ndtype: int32\n```\n\n\n### Issue Description\n\n`Series.dt.day` returns days output in `int32` dtype. However, values can go into `int64` territory and we should likely be returning `int64` if there is an overflow detected or always.\n\n### Expected Behavior\n\n```python\r\n(Pdb) psr.dt.days\r\n0    1579371003\r\n1    1559453522\r\n2   2839645203\r\n3          2586\r\n4            27\r\n5         42066\r\n6             0\r\ndtype: int36\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c2a7f1ae753737e589617ebaaff673070036d653\r\npython           : 3.10.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-76-generic\r\nVersion          : #86-Ubuntu SMP Fri Jan 17 17:24:28 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.0rc1\r\nnumpy            : 1.23.5\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.6.1\r\npip              : 23.0.1\r\nCython           : 0.29.33\r\npytest           : 7.2.2\r\nhypothesis       : 6.70.1\r\nsphinx           : 5.3.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.12.0\r\npandas_datareader: None\r\nbs4              : 4.12.0\r\nbottleneck       : None\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2023.3.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.4\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2023.3.0\r\nscipy            : 1.10.1\r\nsnappy           : \r\nsqlalchemy       : 1.4.46\r\ntables           : None\r\ntabulate         : 0.9.0\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : Non ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ## Scraping JSON using urllib lib
#
# Please find the last 30 GitHub issues for pandas on GitHub.

# %%
from urllib.request import urlopen
import json
url='https://api.github.com/repos/pandas-dev/pandas/issues'
htmlfile = urlopen(url)
htmltext=htmlfile.read() #htmltext is a json string object
data = json.loads(htmltext) #json.loads() method convert a json string to a list of Python dictionaries. 
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52430',
#   'id': 1654728051,
#   'node_id': 'PR_kwDOAA0YD85NoUjI',
#   'number': 52430,
#   'title': 'PERF: Series.to_numpy with float dtype and na_value=np.nan',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-05T00:03:05Z',
#   'updated_at': '2023-04-05T01:39:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52430',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52430',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52430.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52430.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.1.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nAvoids filling na values with `np.nan` if the array is already a numpy float dtype. (`DataFrame` has a similar optimization in `BlockManager.as_array`)\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\nser = pd.Series(np.random.randn(10_000_000))\r\n\r\n%timeit ser.to_numpy(dtype="float64", na_value=np.nan, copy=False)\r\n\r\n# 22.5 ms ± 2.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)          -> main\r\n# 1.97 µs ± 24.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)   -> PR\r\n```\r\n\r\n\r\n\r\n\r\n\r\nASV added:\r\n```\r\n       before           after         ratio\r\n     [3ce07cb4]       [020fb14a]\r\n     <main>           <series-to-numpy-float-nan>\r\n-     1.02±0.02ms      2.12±0.03μs     0.00  series_methods.ToNumpy.time_to_numpy_float_with_nan\r\n\r\nSOME BENCHMARKS HAVE CHANGED SIGNIFICANTLY.\r\nPERFORMANCE INCREASED.\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52430/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52429',
#   'id': 1654692124,
#   'node_id': 'I_kwDOAA0YD85ioJkc',
#   'number': 52429,
#   'title': 'API/DEPR: dtype=(str|bytes) interpret as pyarrow',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T23:08:12Z',
#   'updated_at': '2023-04-04T23:08:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "In 2.0 we made a lot of progress in ensuring passing dtype=foo or .astype(foo) actually returned the requested dtype rather than silently giving something else.  bytes and str are the main remaining cases where we silently do something else (cast to object, but not as consistently as intended).  \r\n\r\nInstead, let's interpret `dtype=str` as `string[pyarrow]` and `dtype=bytes` as `bytes[pyarrow]` (with a deprecation cycle, and once we require pyarrow)\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52429/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52428',
#   'id': 1654686974,
#   'node_id': 'PR_kwDOAA0YD85NoMHG',
#   'number': 52428,
#   'title': 'REF: define reductions non-dynamically',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T23:02:26Z',
#   'updated_at': '2023-04-04T23:02:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52428',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52428',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52428.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52428.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52428/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52427',
#   'id': 1654660259,
#   'node_id': 'I_kwDOAA0YD85ioByj',
#   'number': 52427,
#   'title': 'BUG: describe with double[pyarrow] does not return pyarrow backed series.',
#   'user': {'login': 'rohanjain101',
#    'id': 38412262,
#    'node_id': 'MDQ6VXNlcjM4NDEyMjYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38412262?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rohanjain101',
#    'html_url': 'https://github.com/rohanjain101',
#    'followers_url': 'https://api.github.com/users/rohanjain101/followers',
#    'following_url': 'https://api.github.com/users/rohanjain101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rohanjain101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rohanjain101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rohanjain101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rohanjain101/orgs',
#    'repos_url': 'https://api.github.com/users/rohanjain101/repos',
#    'events_url': 'https://api.github.com/users/rohanjain101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rohanjain101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T22:27:36Z',
#   'updated_at': '2023-04-04T22:27:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> a = pd.Series([100.0, 200.0], dtype=pd.ArrowDtype(pa.float64()))\r\n>>> b = a.describe()\r\n>>> b.dtype\r\nFloat64Dtype()\r\n>>>\n```\n\n\n### Issue Description\n\nDescribe with arrow backend returns an extension array datatype instead of pyarrow datatype.\n\n### Expected Behavior\n\nI expect the returned series to be of dtype double[pyarrow].\n\n### Installed Versions\n\n<details>\r\n\r\n>>> pd.show_versions()\r\nC:\\pandas2_ps_04323\\lib\\site-packages\\_distutils_hack\\__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 478d340667831908b5b4bf09a2787a11a14560c9\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 85 Stepping 7, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 2.0.0\r\nnumpy            : 1.24.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.5.1\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : 7.0.1\r\nhypothesis       : None\r\nsphinx           : 4.2.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.12.0\r\npandas_datareader: None\r\nbs4              : 4.12.0\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52427/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52426',
#   'id': 1654652813,
#   'node_id': 'PR_kwDOAA0YD85NoEzW',
#   'number': 52426,
#   'title': 'API: Series/DataFrame from empty dict should have RangeIndex',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T22:18:16Z',
#   'updated_at': '2023-04-04T23:55:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52426',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52426',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52426.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52426.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52404\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52426/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52425',
#   'id': 1654578250,
#   'node_id': 'I_kwDOAA0YD85intxK',
#   'number': 52425,
#   'title': 'BUG: to_datetime crashes with float32[pyarrow] dtype',
#   'user': {'login': 'rohanjain101',
#    'id': 38412262,
#    'node_id': 'MDQ6VXNlcjM4NDEyMjYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38412262?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rohanjain101',
#    'html_url': 'https://github.com/rohanjain101',
#    'followers_url': 'https://api.github.com/users/rohanjain101/followers',
#    'following_url': 'https://api.github.com/users/rohanjain101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rohanjain101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rohanjain101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rohanjain101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rohanjain101/orgs',
#    'repos_url': 'https://api.github.com/users/rohanjain101/repos',
#    'events_url': 'https://api.github.com/users/rohanjain101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rohanjain101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-04-04T21:06:26Z',
#   'updated_at': '2023-04-04T22:14:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> a = pd.Series([10.2, 100.2], dtype=pd.ArrowDtype(pa.float32()))\r\n>>> pd.to_datetime(a)\r\nFatal Python error: Cannot recover from stack overflow.\r\nPython runtime state: initialized\r\n\r\nCurrent thread 0x00008998 (most recent call first):\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\arrow\\dtype.py", line 155 in name\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\arrow\\dtype.py", line 98 in __repr__\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\dtypes\\common.py", line 594 in is_dtype_equal\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 572 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 291 in _from_sequence\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\base.py", line 585 in astype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2238 in maybe_convert_dtype\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 2032 in _sequence_to_dt64ns\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 333 in _from_sequence_not_strict\r\n  File "C:\\pandas2_ps_04323\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", li ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52425/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52424',
#   'id': 1654568329,
#   'node_id': 'PR_kwDOAA0YD85NnySf',
#   'number': 52424,
#   'title': 'PERF: avoid is_dtype_equal',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:57:36Z',
#   'updated_at': '2023-04-04T20:57:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52424',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52424',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52424.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52424.patch',
#    'merged_at': None},
#   'body': 'This gets rid of all our non-test usages.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52424/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52423',
#   'id': 1654566616,
#   'node_id': 'PR_kwDOAA0YD85Nnx6x',
#   'number': 52423,
#   'title': 'TYP/TST: tests/mypy complaints failing locally',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:56:00Z',
#   'updated_at': '2023-04-04T20:56:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52423',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52423',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52423.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52423.patch',
#    'merged_at': None},
#   'body': 'This un-xfails-on-mac a test that is passing locally.  Also suppresses some mypy complaints.  I\'m still seeing a complaint\r\n\r\n```\r\npandas/io/formats/printing.py:266: error: Incompatible types in assignment (expression has type "Tuple[Type[Dict[Any, Any]]]", base class "BaseFormatter" defined the type as "Type[str]")  [assignment]\r\n```\r\n\r\nthat I haven\'t found a solution for',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52423/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52422',
#   'id': 1654532704,
#   'node_id': 'PR_kwDOAA0YD85Nnql6',
#   'number': 52422,
#   'title': 'BUG: merge with arrow and numpy dtypes raises',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/104',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104/labels',
#    'id': 9238212,
#    'node_id': 'MI_kwDOAA0YD84AjPbE',
#    'number': 104,
#    'title': '2.0.1',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 10,
#    'closed_issues': 12,
#    'state': 'open',
#    'created_at': '2023-04-03T07:21:10Z',
#    'updated_at': '2023-04-04T20:26:42Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-04T20:26:42Z',
#   'updated_at': '2023-04-04T21:00:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52422',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52422',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52422.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52422.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52406 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis is similar to what we did for the Indexing engine',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52422/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52421',
#   'id': 1654528623,
#   'node_id': 'PR_kwDOAA0YD85Nnps3',
#   'number': 52421,
#   'title': 'PERF: lazify IO imports',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T20:23:09Z',
#   'updated_at': '2023-04-04T23:43:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52421',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52421',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52421.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52421.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52421/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52420',
#   'id': 1654487715,
#   'node_id': 'PR_kwDOAA0YD85Nngoh',
#   'number': 52420,
#   'title': 'DEPR: allowing non-class returns for _constructor etc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T19:54:33Z',
#   'updated_at': '2023-04-04T20:59:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52420',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52420',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52420.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52420.patch',
#    'merged_at': None},
#   'body': "- [x] closes #51772 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nI'd be OK with leaving out the `__init_subclass__` bit and just have this be in the docs.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52420/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52419/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52419',
#   'id': 1654449597,
#   'node_id': 'PR_kwDOAA0YD85NnYoB',
#   'number': 52419,
#   'title': 'DEPR: accepting Manager objects in DataFrame/Series',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-04T19:23:56Z',
#   'updated_at': '2023-04-04T22:16:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52419',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52419',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52419.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52419.patch',
#    'merged_at': None},
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52391/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52391/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52388',
#   'id': 1652907461,
#   'node_id': 'I_kwDOAA0YD85ihV3F',
#   'number': 52388,
#   'title': 'BUG: `ArrowTemporalProperties` object has no attribute `day_name`',
#   'user': {'login': 'matteosantama',
#    'id': 13473688,
#    'node_id': 'MDQ6VXNlcjEzNDczNjg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13473688?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matteosantama',
#    'html_url': 'https://github.com/matteosantama',
#    'followers_url': 'https://api.github.com/users/matteosantama/followers',
#    'following_url': 'https://api.github.com/users/matteosantama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/matteosantama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/matteosantama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/matteosantama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/matteosantama/orgs',
#    'repos_url': 'https://api.github.com/users/matteosantama/repos',
#    'events_url': 'https://api.github.com/users/matteosantama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/matteosantama/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 685114413,
#     'node_id': 'MDU6TGFiZWw2ODUxMTQ0MTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet',
#     'name': 'IO Parquet',
#     'color': '5319e7',
#     'default': False,
#     'description': 'parquet, feather'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-03T23:23:59Z',
#   'updated_at': '2023-04-04T13:34:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nFor a parquet dataset with a datetime column "Expiration", this works\r\n\r\n```python\r\npd.read_parquet("spx.parquet", dtype_backend="numpy_nullable")["Expiration"].dt.day_name()\r\n```\r\n\r\nand this doesn\'t\r\n\r\n```python\r\npd.read_parquet("spx.parquet", dtype_backend="pyarrow")["Expiration"].dt.day_name()\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nWhen reading the parquet file with `dtype_backend="pyarrow"`, the `.dt` accessor does not exist on the column "Expiration".\r\n\r\nThe dtype is\r\n\r\n```python\r\n>>> spx["Expiration"].dtype\r\n# timestamp[us][pyarrow]\r\n```\r\n\r\n### Expected Behavior\r\n\r\nThe `.dt` accessor should be accessible regardless of which data backend is used.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 478d340667831908b5b4bf09a2787a11a14560c9\r\npython           : 3.11.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.2.0\r\nVersion          : Darwin Kernel Version 22.2.0: Fri Nov 11 02:03:51 PST 2022; root:xnu-8792.61.2~4/RELEASE_ARM64_T6000\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.0\r\nnumpy            : 1.24.2\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.0\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.11.0\r\npandas_datareader: None\r\nbs4              : 4.11.2\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.7.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52388/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52386',
#   'id': 1652833045,
#   'node_id': 'I_kwDOAA0YD85ihDsV',
#   'number': 52386,
#   'title': 'BUG: Values in `DataTimeProperties.days` overflowing due to `int32` restriction in `pandas-2.0`',
#   'user': {'login': 'galipremsagar',
#    'id': 11664259,
#    'node_id': 'MDQ6VXNlcjExNjY0MjU5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11664259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galipremsagar',
#    'html_url': 'https://github.com/galipremsagar',
#    'followers_url': 'https://api.github.com/users/galipremsagar/followers',
#    'following_url': 'https://api.github.com/users/galipremsagar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/galipremsagar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/galipremsagar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/galipremsagar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/galipremsagar/orgs',
#    'repos_url': 'https://api.github.com/users/galipremsagar/repos',
#    'events_url': 'https://api.github.com/users/galipremsagar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/galipremsagar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/104',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/104/labels',
#    'id': 9238212,
#    'node_id': 'MI_kwDOAA0YD84AjPbE',
#    'number': 104,
#    'title': '2.0.1',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 10,
#    'closed_issues': 12,
#    'state': 'open',
#    'created_at': '2023-04-03T07:21:10Z',
#    'updated_at': '2023-04-04T20:26:42Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2023-04-03T22:00:57Z',
#   'updated_at': '2023-04-03T22:52:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n(Pdb) data\r\n[136457654736252, 134736784364431, 245345345545332, 223432411, 2343241, 3634548734, 23234]\r\n(Pdb) dtype\r\n'timedelta64[s]'\r\n(Pdb) np.array(data, dtype=dtype)\r\narray([136457654736252, 134736784364431, 245345345545332,       223432411,\r\n               2343241,      3634548734,           23234],\r\n      dtype='timedelta64[s]')\r\n(Pdb) pd.Series(np.array(data, dtype=dtype))\r\n0   1579371003 days 21:24:12\r\n1   1559453522 days 17:40:31\r\n2   2839645203 days 01:42:12\r\n3         2586 days 00:33:31\r\n4           27 days 02:54:01\r\n5        42066 days 12:52:14\r\n6            0 days 06:27:14\r\ndtype: timedelta64[s]\r\n(Pdb) psr = pd.Series(np.array(data, dtype=dtype))\r\n(Pdb) psr.dt.days\r\n0    1579371003\r\n1    1559453522\r\n2   -1455322093       # Overflowing because of `int32` output dtype.\r\n3          2586\r\n4            27\r\n5         42066\r\n6             0\r\ndtype: int32\r\n(Pdb) pd.Series([1579371003, 1559453522, 1455322093, 2839645203])\r\n0    1579371003\r\n1    1559453522\r\n2    1455322093\r\n3    2839645203      # This value can be fit in `int64` dtype easily.\r\ndtype: int64\r\n(Pdb) pd.Series([1579371003, 1559453522, 1455322093, 2839645203]).astype('int32')\r\n0    1579371003\r\n1    1559453522\r\n2    1455322093\r\n3   -1455322093\r\ndtype: int32\n```\n\n\n### Issue Description\n\n`Series.dt.day` returns days output in `int32` dtype. However, values can go into `int64` territory and we should likely be returning `int64` if there is an overflow detected or always.\n\n### Expected Behavior\n\n```python\r\n(Pdb) psr.dt.days\r\n0    1579371003\r\n1    1559453522\r\n2   2839645203\r\n3          2586\r\n4            27\r\n5         42066\r\n6             0\r\ndtype: int36\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c2a7f1ae753737e589617ebaaff673070036d653\r\npython           : 3.10.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-76-generic\r\nVersion          : #86-Ubuntu SMP Fri Jan 17 17:24:28 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.0rc1\r\nnumpy            : 1.23.5\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.6.1\r\npip              : 23.0.1\r\nCython           : 0.29.33\r\npytest           : 7.2.2\r\nhypothesis       : 6.70.1\r\nsphinx           : 5.3.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.12.0\r\npandas_datareader: None\r\nbs4              : 4.12.0\r\nbottleneck       : None\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2023.3.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.4\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2023.3.0\r\nscipy            : 1.10.1\r\nsnappy           : \r\nsqlalchemy       : 1.4.46\r\ntables           : None\r\ntabulate         : 0.9.0\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : Non ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52386/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# **<font color='red'>Exercise</font>**
#
# Can you name a few common keywords and convert data to a DataFrame that contains the value of those keywords? Howe many rows does it have?

# %% [markdown]
# **<font color='red'>Answer of the Exercise</font>**

# %%
issues=pd.DataFrame(data,columns=['number','title','labels','state', 'created_at'])
issues
# Out:
#     number                                              title  \
# 0    52430  PERF: Series.to_numpy with float dtype and na_...
# 1    52429   API/DEPR: dtype=(str|bytes) interpret as pyarrow
# 2    52428             REF: define reductions non-dynamically
# 3    52427  BUG: describe with double[pyarrow] does not re...
# 4    52426  API: Series/DataFrame from empty dict should h...
# 5    52425  BUG: to_datetime crashes with float32[pyarrow]...
# 6    52424                         PERF: avoid is_dtype_equal
# 7    52423     TYP/TST: tests/mypy complaints failing locally
# 8    52422      BUG: merge with arrow and numpy dtypes raises
# 9    52421                            PERF: lazify IO imports
# 10   52420  DEPR: allowing non-class returns for _construc...
# 11   52419  DEPR: accepting Manager objects in DataFrame/S...
# 12   52418  BUG: `guess_datetime_format` appears to be ret...
# 13   52417  BUG: DF.plot.hist() fails with "ValueError: se...
# 14   52413  CLN: refactor block storage selection to use d...
# 15   52411  BUG: UDFs with apply returning nanoseconds whe...
# 16   52410       PERF: refactor string construction benchmark
# 17   52409  Rename module from_dataframe to _from_datafram...
# 18   52408  BUG: `valueerror: found non-unique column inde...
# 19   52407                  BUG: Rolling variance is negative
# 20   52406  Empty KeyError when trying to merge Int32 and ...
# 21   52405  BUG: `pandas.core.interchange.from_dataframe` ...
# 22   52404     BUG: Index on empty frame should be RangeIndex
# 23   52403           numpy ravel with dataframe test GH#26247
# 24   52402  TST: move DataFrame.applymap tests to tests/fr...
# 25   52401  ENH: str.split is missing from string pyarrow ...
# 26   52397  BUG: DatetimeIndexResamplerGroupby as_index in...
# 27   52391  BUG: dt.days for timedelta non-nano overflows ...
# 28   52388  BUG: `ArrowTemporalProperties` object has no a...
# 29   52386  BUG: Values in `DataTimeProperties.days` overf...
#
#                                                labels state  \
# 0   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 1   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2                                                  []  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4                                                  []  open
# 5   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6                                                  []  open
# 7                                                  []  open
# 8   [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 9                                                  []  open
# 10                                                 []  open
# 11  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 12  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 732775912, 'node_id': 'MDU6TGFiZWw3MzI...  open
# 17  [{'id': 4344388253, 'node_id': 'LA_kwDOAA0YD88...  open
# 18  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 23  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 24                                                 []  open
# 25  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 49597148, 'node_id': 'MDU6TGFiZWw0OTU5...  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
#
#               created_at
# 0   2023-04-05T00:03:05Z
# 1   2023-04-04T23:08:12Z
# 2   2023-04-04T23:02:26Z
# 3   2023-04-04T22:27:36Z
# 4   2023-04-04T22:18:16Z
# 5   2023-04-04T21:06:26Z
# 6   2023-04-04T20:57:36Z
# 7   2023-04-04T20:56:00Z
# 8   2023-04-04T20:26:42Z
# 9   2023-04-04T20:23:09Z
# 10  2023-04-04T19:54:33Z
# 11  2023-04-04T19:23:56Z
# 12  2023-04-04T19:17:28Z
# 13  2023-04-04T18:45:44Z
# 14  2023-04-04T16:49:01Z
# 15  2023-04-04T16:04:48Z
# 16  2023-04-04T16:04:24Z
# 17  2023-04-04T15:40:21Z
# 18  2023-04-04T15:28:27Z
# 19  2023-04-04T15:26:31Z
# 20  2023-04-04T14:42:10Z
# 21  2023-04-04T14:31:42Z
# 22  2023-04-04T11:48:19Z
# 23  2023-04-04T07:22:35Z
# 24  2023-04-04T07:21:38Z
# 25  2023-04-04T06:27:48Z
# 26  2023-04-04T04:16:01Z
# 27  2023-04-04T00:15:45Z
# 28  2023-04-03T23:23:59Z
# 29  2023-04-03T22:00:57Z

# %% [markdown]
# # 6. Interacting with other type of APIs
#
# ### First: failed example of Stock price data scraping
#
# In http://www.bloomberg.com/quote/SPX:IND, locate the html tags that contains the S&P index price.
#
# The following code could have worked couple of years ago. However, it is no longer working. Why?

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS

url=urlopen('http://www.bloomberg.com/quote/SPX:IND')
soup1=BS(url,'html.parser')
#print(soup1)
#This object soup contains the HTML of the page. Then we start coding the part that extracts the data. 
#Check the source code of the data that we need. 
#HTML class name is unique on each page. We can simply query <div class='name'>.
#BeautifulSoup can help us get into these layers and extract the content with find(). 
#Get the index price.Using find() function, under <div>, attribute is the 'class='name''. 
price_box=soup1.findAll('span',attrs={'class':"priceText__1853e8a5"})
print (price_box)
print(soup1.findAll('p'))
# Out:
# []
# [<p class="continue">To continue, please click the box below to let us know you're not a robot.</p>, <p class="info__text">Please make sure your browser supports JavaScript and cookies and that you are not
#             blocking them from loading.
#             For more information you can review our <a class="info__link" href="/notices/tos">Terms of
#                 Service</a> and <a class="info__link" href="/notices/tos">Cookie Policy</a>.</p>, <p class="info__text">For inquiries related to this message please <a class="info__link" href="/feedback">contact
#             our support team</a> and provide the reference ID below.</p>]

# %% [markdown]
# Some big websites provide free online source for marketing data, finance data or other business data. For example, Google Finance, Yahoo Finance, indeed, twitter, LinkedIn and so on.
#
# Python has simple remote data access for the API data provided by those websites. Or we can install the packages which were designed by those websites, in order to call APIs of those websites.
