# %%
# !pip install category_encoders
# !pip install pingouin
# !pip install xgboost

# %%
# basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# stats libraries
import pingouin as pg
import ppscore as pps
import statsmodels.api as sm
import scipy.stats as stats

# feature processing libraries
from sklearn.preprocessing import KBinsDiscretizer, MinMaxScaler
from category_encoders.target_encoder import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split, cross_val_predict
from sklearn.feature_selection import SelectFromModel

# models & reporting
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, BaggingClassifier
from sklearn.metrics import fbeta_score, confusion_matrix, classification_report

# %%
dirty_hair = pd.read_csv('Predict Hair Fall.csv')

# %%
dirty_hair.head()
# Out:
#        Id Genetics Hormonal Changes Medical Conditions  \
# 0  133992      Yes               No            No Data
# 1  148393       No               No             Eczema
# 2  155074       No               No         Dermatosis
# 3  118261      Yes              Yes           Ringworm
# 4  111915       No               No          Psoriasis
#
#   Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                  No Data      Magnesium deficiency  Moderate   19
# 1              Antibiotics      Magnesium deficiency      High   43
# 2         Antifungal Cream        Protein deficiency  Moderate   26
# 3              Antibiotics        Biotin Deficiency   Moderate   46
# 4                 Accutane           Iron deficiency  Moderate   30
#
#   Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   Hair Loss
# 0                    Yes                   Yes      No           No          0
# 1                    Yes                   Yes      No           No          0
# 2                    Yes                   Yes      No          Yes          0
# 3                    Yes                   Yes      No           No          0
# 4                     No                   Yes     Yes           No          1

# %%
def hasDuplicates(df):
    duplicates = df.duplicated()
    if duplicates.any():

        print("\nDuplicates exist in the DataFrame.")
    else:
        print("\nNo duplicates found in the DataFrame.")

        
def hasMissingVals(df):
    missing_values = df.isna()

    # Check if any missing values exist
    if missing_values.any().any():
        print("\nMissing values exist in the DataFrame.")
    else:
        print("\nNo missing values found in the DataFrame.")

def count_outliers(series):
    count = 0
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    for val in series:
        if (val < lower_bound) | (val > upper_bound):
            count += 1
    return print('There are', count, "outliers in this feature")

def hasOutliers(df):
    outliers = pd.DataFrame()
    for column in df.columns:
        try:
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - (1.5 * IQR)
            upper_bound = Q3 + (1.5 * IQR)
            outliers[column] = (df[column] < lower_bound) | (df[column] > upper_bound)
        except: continue 
    if outliers.any().any():
        print("\nOutliers exist in the DataFrame.")
    else:
        print("\nNo outliers found in the DataFrame.")

        
def catMap(df):
    for column in df.columns:
        if df[column].dtype == 'object':
            mapping = {category:n for n, category in enumerate(df[column].unique())}
            df[column] = df[column].map(mapping)
    return df

def f2_func(y_true, y_pred):
    f2_score = fbeta_score(y_true, y_pred, beta=2)
    return f2_score

def f2_scorer():
    return make_scorer(f2_func)

# %%
# take spaces out of 
dirty_hair.columns = dirty_hair.columns.str.strip().str.replace(" ", "_")

# %%
# remove rows where the value 'No Data' is present and keep the first record with a certain ID #
hasDuplicates(dirty_hair)
print("Number of rows with duplicated Id:", dirty_hair['Id'].duplicated().sum())
print("Before removing rows with 'No Data' and with duplicated Id:", len(dirty_hair))
dirty_hair = dirty_hair[(dirty_hair['Medical_Conditions'] != 'No Data') & (dirty_hair['Medications_&_Treatments'] != 'No Data') & (dirty_hair['Nutritional_Deficiencies'] != 'No Data')]
clean_hair = dirty_hair.drop_duplicates(subset='Id', keep='first')
print("After removing rows with 'No Data' and with duplicated Id:", len(clean_hair))
print("Rows dropped:", 999-807)
# Out:
# No duplicates found in the DataFrame.
# Number of rows with duplicated Id: 4
# Before removing rows with 'No Data' and with duplicated Id: 999
# After removing rows with 'No Data' and with duplicated Id: 807
# Rows dropped: 192

# %%
eda_df = clean_hair.copy()
eda_df.columns
# Out:
# Index(['Id', 'Genetics', 'Hormonal_Changes', 'Medical_Conditions',
#        'Medications_&_Treatments', 'Nutritional_Deficiencies', 'Stress', 'Age',
#        'Poor_Hair_Care_Habits', 'Environmental_Factors', 'Smoking',
#        'Weight_Loss', 'Hair_Loss'],
#       dtype='object')

# %%
categorical_df = pd.DataFrame()
for col in eda_df.columns:
    if len(eda_df[col].unique()) <= 3:
        categorical_df[col] = eda_df[col]

fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()

for i, (column, data) in enumerate(categorical_df.items()):
    ax = axes[i]  # Get the current axis
    ax.set_title(column)  # Set title for the pie chart
    counts = data.value_counts()  # Count occurrences of each unique value
    ax.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140) 
    
plt.show()

# %%
# visualization to check normality
plt.figure()
sm.qqplot(eda_df['Age'], line = 'q', lw = 2.1)
plt.title(f'Age', color = 'black')
plt.show()

# %%
# confirm not normal
pg.normality(eda_df['Age'])
# Out:
#             W          pval  normal
# Age  0.972724  3.902338e-11   False

# %%
# check for similar variance within age 
pg.homoscedasticity(eda_df, dv='Age', group='Hair_Loss')
# Out:
#                W      pval  equal_var
# levene  2.144099  0.143509       True

# %%
# confirm similar variance for outliers
count_outliers(eda_df['Age'])
# Out:
# There are 0 outliers in this feature

# %%
categorical_features = categorical_df.columns.tolist()

# Perform chi-square test for each pair of categorical features
for i in range(len(categorical_features)):
    for j in range(i+1, len(categorical_features)):
        if categorical_features[i] == 'Hair_Loss' or categorical_features[j] == 'Hair_Loss':
            _, _, stats = pg.chi2_independence(categorical_df, categorical_features[i], categorical_features[j])
            stats = stats.style.background_gradient(cmap = 'Reds', subset = 'pval')
            print(f"Chi-square test statistics for {categorical_features[i]} and {categorical_features[j]}")
            display(stats)
        else:
            continue
# Out:
# Chi-square test statistics for Genetics and Hair_Loss
# <style type="text/css">
# #T_9df11_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9df11_row1_col4 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_9df11_row2_col4 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_9df11_row3_col4 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_9df11_row4_col4 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_9df11_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_9df11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9df11_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_9df11_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_9df11_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_9df11_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_9df11_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_9df11_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_9df11_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9df11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9df11_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_9df11_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_9df11_row0_col2" class="data row0 col2" >1.869502</td>
#       <td id="T_9df11_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_9df11_row0_col4" class="data row0 col4" >0.171532</td>
#       <td id="T_9df11_row0_col5" class="data row0 col5" >0.048131</td>
#       <td id="T_9df11_row0_col6" class="data row0 col6" >0.277141</td>
#     </tr>
#     <tr>
#       <th id="T_9df11_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9df11_row1_col0" class="data row1 col0" >cressie-read</td>
#       <td id="T_9df11_row1_col1" class="data row1 col1" >0.666667</td>
#       <td id="T_9df11_row1_col2" class="data row1 col2" >1.869655</td>
#       <td id="T_9df11_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_9df11_row1_col4" class="data row1 col4" >0.171515</td>
#       <td id="T_9df11_row1_col5" class="data row1 col5" >0.048133</td>
#       <td id="T_9df11_row1_col6" class="data row1 col6" >0.277159</td>
#     </tr>
#     <tr>
#       <th id="T_9df11_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9df11_row2_col0" class="data row2 col0" >log-likelihood</td>
#       <td id="T_9df11_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_9df11_row2_col2" class="data row2 col2" >1.870201</td>
#       <td id="T_9df11_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_9df11_row2_col4" class="data row2 col4" >0.171452</td>
#       <td id="T_9df11_row2_col5" class="data row2 col5" >0.048140</td>
#       <td id="T_9df11_row2_col6" class="data row2 col6" >0.277226</td>
#     </tr>
#     <tr>
#       <th id="T_9df11_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9df11_row3_col0" class="data row3 col0" >freeman-tukey</td>
#       <td id="T_9df11_row3_col1" class="data row3 col1" >-0.500000</td>
#       <td id="T_9df11_row3_col2" class="data row3 col2" >1.870823</td>
#       <td id="T_9df11_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9df11_row3_col4" class="data row3 col4" >0.171381</td>
#       <td id="T_9df11_row3_col5" class="data row3 col5" >0.048148</td>
#       <td id="T_9df11_row3_col6" class="data row3 col6" >0.277302</td>
#     </tr>
#     <tr>
#       <th id="T_9df11_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9df11_row4_col0" class="data row4 col0" >mod-log-likelihood</td>
#       <td id="T_9df11_row4_col1" class="data row4 col1" >-1.000000</td>
#       <td id="T_9df11_row4_col2" class="data row4 col2" >1.871625</td>
#       <td id="T_9df11_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_9df11_row4_col4" class="data row4 col4" >0.171289</td>
#       <td id="T_9df11_row4_col5" class="data row4 col5" >0.048158</td>
#       <td id="T_9df11_row4_col6" class="data row4 col6" >0.277399</td>
#     </tr>
#     <tr>
#       <th id="T_9df11_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9df11_row5_col0" class="data row5 col0" >neyman</td>
#       <td id="T_9df11_row5_col1" class="data row5 col1" >-2.000000</td>
#       <td id="T_9df11_row5_col2" class="data row5 col2" >1.873776</td>
#       <td id="T_9df11_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_9df11_row5_col4" class="data row5 col4" >0.171043</td>
#       <td id="T_9df11_row5_col5" class="data row5 col5" >0.048186</td>
#       <td id="T_9df11_row5_col6" class="data row5 col6" >0.277661</td>
#     </tr>
#   </tbody>
# </table>
# Chi-square test statistics for Hormonal_Changes and Hair_Loss
# <style type="text/css">
# #T_88774_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_88774_row1_col4 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_88774_row2_col4 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_88774_row3_col4 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_88774_row4_col4 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_88774_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_88774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88774_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_88774_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_88774_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_88774_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_88774_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_88774_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_88774_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88774_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_88774_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_88774_row0_col2" class="data row0 col2" >0.143161</td>
#       <td id="T_88774_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_88774_row0_col4" class="data row0 col4" >0.705159</td>
#       <td id="T_88774_row0_col5" class="data row0 col5" >0.013319</td>
#       <td id="T_88774_row0_col6" class="data row0 col6" >0.066556</td>
#     </tr>
#     <tr>
#       <th id="T_88774_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
#   color: #f1f1f1;
# }
# #T_79524_row1_col4 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_79524_row2_col4 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_79524_row3_col4 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_79524_row4_col4 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_79524_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_79524">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79524_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_79524_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_79524_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_79524_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_79524_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_79524_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_79524_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79524_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79524_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_79524_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_79524_row0_col2" class="data row0 col2" >0.386529</td>
#       <td id="T_79524_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_79524_row0_col4" class="data row0 col4" >0.824264</td>
#       <td id="T_79524_row0_col5" class="data row0 col5" >0.021885</td>
#       <td id="T_79524_row0_col6" class="data row0 col6" >0.080252</td>
#     </tr>
#     <tr>
#       <th id="T_79524_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79524_row1_col0" class="data row1 col0" >cressie-read</td>
#       <td id="T_79524_row1_col1" class="data row1 col1" >0.666667</td>
#       <td id="T_79524_row1_col2" class="data row1 col2" >0.386543</td>
#       <td id="T_79524_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_79524_row1_col4" class="data row1 col4" >0.824258</td>
#       <td id="T_79524_row1_col5" class="data row1 col5" >0.021886</td>
#       <td id="T_79524_row1_col6" class="data row1 col6" >0.080253</td>
#     </tr>
#     <tr>
#       <th id="T_79524_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79524_row2_col0" class="data row2 col0" >log-likelihood</td>
#       <td id="T_79524_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_79524_row2_col2" class="data row2 col2" >0.386583</td>
#       <td id="T_79524_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_79524_row2_col4" class="data row2 col4" >0.824241</td>
#       <td id="T_79524_row2_col5" class="data row2 col5" >0.021887</td>
#       <td id="T_79524_row2_col6" class="data row2 col6" >0.080257</td>
#     </tr>
#     <tr>
#       <th id="T_79524_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79524_row3_col0" class="data row3 col0" >freeman-tukey</td>
#       <td id="T_79524_row3_col1" class="data row3 col1" >-0.500000</td>
#       <td id="T_79524_row3_col2" class="data row3 col2" >0.386625</td>
#       <td id="T_79524_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_79524_row3_col4" class="data row3 col4" >0.824224</td>
#       <td id="T_79524_row3_col5" class="data row3 col5" >0.021888</td>
#       <td id="T_79524_row3_col6" class="data row3 col6" >0.080260</td>
#     </tr>
#     <tr>
#       <th id="T_79524_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79524_row4_col0" class="data row4 col0" >mod-log-likelihood</td>
#       <td id="T_79524_row4_col1" class="data row4 col1" >-1.000000</td>
#       <td id="T_79524_row4_col2" class="data row4 col2" >0.386677</td>
#       <td id="T_79524_row4_col3" class="data row4 col3" >2.000000</td>
#       <td id="T_79524_row4_col4" class="data row4 col4" >0.824203</td>
#       <td id="T_79524_row4_col5" class="data row4 col5" >0.021890</td>
#       <td id="T_79524_row4_col6" class="data row4 col6" >0.080264</td>
#     </tr>
#     <tr>
#       <th id="T_79524_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_79524_row5_col0" class="data row5 col0" >neyman</td>
#       <td id="T_79524_row5_col1" class="data row5 col1" >-2.000000</td>
#       <td id="T_79524_row5_col2" class="data row5 col2" >0.386810</td>
#       <td id="T_79524_row5_col3" class="data row5 col3" >2.000000</td>
#       <td id="T_79524_row5_col4" class="data row5 col4" >0.824148</td>
#       <td id="T_79524_row5_col5" class="data row5 col5" >0.021893</td>
#       <td id="T_79524_row5_col6" class="data row5 col6" >0.080275</td>
#     </tr>
#   </tbody>
# </table>
# Chi-square test statistics for Poor_Hair_Care_Habits and Hair_Loss
# <style type="text/css">
# #T_0eaa9_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0eaa9_row1_col4 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_0eaa9_row2_col4 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_0eaa9_row3_col4 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_0eaa9_row4_col4 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_0eaa9_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0eaa9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eaa9_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_0eaa9_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_0eaa9_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_0eaa9_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_0eaa9_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_0eaa9_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_0eaa9_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eaa9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0eaa9_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_0eaa9_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_0eaa9_row0_col2" class="data row0 col2" >1.504199</td>
#       <td id="T_0eaa9_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_0eaa9_row0_col4" class="data row0 col4" >0.220026</td>
#       <td id="T_0eaa9_row0_col5" class="data row0 col5" >0.043173</td>
#       <td id="T_0eaa9_row0_col6" class="data row0 col6" >0.232345</td>
#     </tr>
#     <tr>
#       <th id="T_0eaa9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
# <style type="text/css">
# #T_d5362_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d5362_row1_col4 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_d5362_row2_col4 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_d5362_row3_col4 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_d5362_row4_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_d5362_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d5362">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5362_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_d5362_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_d5362_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_d5362_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_d5362_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_d5362_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_d5362_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5362_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5362_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_d5362_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d5362_row0_col2" class="data row0 col2" >0.001689</td>
#       <td id="T_d5362_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_d5362_row0_col4" class="data row0 col4" >0.967216</td>
#       <td id="T_d5362_row0_col5" class="data row0 col5" >0.001447</td>
#       <td id="T_d5362_row0_col6" class="data row0 col6" >0.050194</td>
#     </tr>
#     <tr>
#       <th id="T_d5362_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5362_row1_col0" class="data row1 col0" >cressie-read</td>
#       <td id="T_d5362_row1_col1" class="data row1 col1" >0.666667</td>
#       <td id="T_d5362_row1_col2" class="data row1 col2" >0.001689</td>
#       <td id="T_d5362_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_d5362_row1_col4" class="data row1 col4" >0.967216</td>
#       <td id="T_d5362_row1_col5" class="data row1 col5" >0.001447</td>
#       <td id="T_d5362_row1_col6" class="data row1 col6" >0.050194</td>
#     </tr>
#     <tr>
#       <th id="T_d5362_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5362_row2_col0" class="data row2 col0" >log-likelihood</td>
#       <td id="T_d5362_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_d5362_row2_col2" class="data row2 col2" >0.001689</td>
#       <td id="T_d5362_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_d5362_row2_col4" class="data row2 col4" >0.967216</td>
#       <td id="T_d5362_row2_col5" class="data row2 col5" >0.001447</td>
#       <td id="T_d5362_row2_col6" class="data row2 col6" >0.050194</td>
#     </tr>
#     <tr>
#       <th id="T_d5362_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5362_row3_col0" class="data row3 col0" >freeman-tukey</td>
#       <td id="T_d5362_row3_col1" class="data row3 col1" >-0.500000</td>
#       <td id="T_d5362_row3_col2" class="data row3 col2" >0.001689</td>
#       <td id="T_d5362_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d5362_row3_col4" class="data row3 col4" >0.967216</td>
#       <td id="T_d5362_row3_col5" class="data row3 col5" >0.001447</td>
#       <td id="T_d5362_row3_col6" class="data row3 col6" >0.050194</td>
#     </tr>
#     <tr>
#       <th id="T_d5362_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5362_row4_col0" class="data row4 col0" >mod-log-likelihood</td>
#       <td id="T_d5362_row4_col1" class="data row4 col1" >-1.000000</td>
#       <td id="T_d5362_row4_col2" class="data row4 col2" >0.001689</td>
#       <td id="T_d5362_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_d5362_row4_col4" class="data row4 col4" >0.967216</td>
#       <td id="T_d5362_row4_col5" class="data row4 col5" >0.001447</td>
#       <td id="T_d5362_row4_col6" class="data row4 col6" >0.050194</td>
#     </tr>
#     <tr>
#       <th id="T_d5362_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5362_row5_col0" class="data row5 col0" >neyman</td>
#       <td id="T_d5362_row5_col1" class="data row5 col1" >-2.000000</td>
#       <td id="T_d5362_row5_col2" class="data row5 col2" >0.001689</td>
#       <td id="T_d5362_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_d5362_row5_col4" class="data row5 col4" >0.967216</td>
#       <td id="T_d5362_row5_col5" class="data row5 col5" >0.001447</td>
#       <td id="T_d5362_row5_col6" class="data row5 col6" >0.050194</td>
#     </tr>
#   </tbody>
# </table>
# Chi-square test statistics for Smoking and Hair_Loss
# <style type="text/css">
# #T_79f4d_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_79f4d_row1_col4 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_79f4d_row2_col4 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_79f4d_row3_col4 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_79f4d_row4_col4 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_79f4d_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_79f4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79f4d_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_79f4d_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_79f4d_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_79f4d_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_79f4d_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_79f4d_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_79f4d_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79f4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79f4d_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_79f4d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_79f4d_row0_col2" class="data row0 col2" >2.558144</td>
#       <td id="T_79f4d_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_79f4d_row0_col4" class="data row0 col4" >0.109727</td>
#       <td id="T_79f4d_row0_col5" class="data row0 col5" >0.056302</td>
#       <td id="T_79f4d_row0_col6" class="data row0 col6" >0.359406</td>
#     </tr>
#     <tr>
#       <th id="T_79f4d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
# Chi-square test statistics for Weight_Loss and Hair_Loss
# <style type="text/css">
# #T_849f2_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_849f2_row1_col4 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_849f2_row2_col4 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_849f2_row3_col4 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_849f2_row4_col4 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_849f2_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_849f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_849f2_level0_col0" class="col_heading level0 col0" >test</th>
#       <th id="T_849f2_level0_col1" class="col_heading level0 col1" >lambda</th>
#       <th id="T_849f2_level0_col2" class="col_heading level0 col2" >chi2</th>
#       <th id="T_849f2_level0_col3" class="col_heading level0 col3" >dof</th>
#       <th id="T_849f2_level0_col4" class="col_heading level0 col4" >pval</th>
#       <th id="T_849f2_level0_col5" class="col_heading level0 col5" >cramer</th>
#       <th id="T_849f2_level0_col6" class="col_heading level0 col6" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_849f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_849f2_row0_col0" class="data row0 col0" >pearson</td>
#       <td id="T_849f2_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_849f2_row0_col2" class="data row0 col2" >1.745839</td>
#       <td id="T_849f2_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_849f2_row0_col4" class="data row0 col4" >0.186401</td>
#       <td id="T_849f2_row0_col5" class="data row0 col5" >0.046512</td>
#       <td id="T_849f2_row0_col6" class="data row0 col6" >0.262038</td>
#     </tr>
#     <tr>
#       <th id="T_849f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_849f2_row1_col0" class="data row1 col0" >cressie-read</td>
#       <td id="T_849f2_row1_col1" class="data row1 col1" >0.666667</td>
#       <td id="T_849f2_row1_col2" class="data row1 col2" >1.746002</td>
#       <td id="T_849f2_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_849f2_row1_col4" class="data row1 col4" >0.186380</td>
#       <td id="T_849f2_row1_col5" class="data row1 col5" >0.046514</td>
#       <td id="T_849f2_row1_col6" class="data row1 col6" >0.262058</td>
#     </tr>
#     <tr>
#       <th id="T_849f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_849f2_row2_col0" class="data row2 col0" >log-likelihood</td>
#       <td id="T_849f2_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_849f2_row2_col2" class="data row2 col2" >1.746541</td>
#       <td id="T_849f2_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_849f2_row2_col4" class="data row2 col4" >0.186312</td>
#       <td id="T_849f2_row2_col5" class="data row2 col5" >0.046521</td>
#       <td id="T_849f2_row2_col6" class="data row2 col6" >0.262124</td>
#     </tr>
#     <tr>
#       <th id="T_849f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_849f2_row3_col0" class="data row3 col0" >freeman-tukey</td>
#       <td id="T_849f2_row3_col1" class="data row3 col1" >-0.500000</td>
#       <td id="T_849f2_row3_col2" class="data row3 col2" >1.747131</td>
#       <td id="T_849f2_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_849f2_row3_col4" class="data row3 col4" >0.186238</td>
#       <td id="T_849f2_row3_col5" class="data row3 col5" >0.046529</td>
#       <td id="T_849f2_row3_col6" class="data row3 col6" >0.262196</td>
#     </tr>
#     <tr>
#       <th id="T_849f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_849f2_row4_col0" class="data row4 col0" >mod-log-likelihood</td>
#       <td id="T_849f2_row4_col1" class="data row4 col1" >-1.000000</td>
#       <td id="T_849f2_row4_col2" class="data row4 col2" >1.747882</td>
#       <td id="T_849f2_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_849f2_row4_col4" class="data row4 col4" >0.186143</td>
#       <td id="T_849f2_row4_col5" class="data row4 col5" >0.046539</td>
#       <td id="T_849f2_row4_col6" class="data row4 col6" >0.262288</td>
#     </tr>
#     <tr>
#       <th id="T_849f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_849f2_row5_col0" class="data row5 col0" >neyman</td>
#       <td id="T_849f2_row5_col1" class="data row5 col1" >-2.000000</td>
#       <td id="T_849f2_row5_col2" class="data row5 col2" >1.749864</td>
#       <td id="T_849f2_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_849f2_row5_col4" class="data row5 col4" >0.185894</td>
#       <td id="T_849f2_row5_col5" class="data row5 col5" >0.046566</td>
#       <td id="T_849f2_row5_col6" class="data row5 col6" >0.262531</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_matrix_pps = pps.matrix(eda_df.drop('Id', axis=1))[['x','y','ppscore']].pivot_table(index = 'y', 
                                                                    columns = 'x', 
                                                                    values = 'ppscore')
plt.figure(figsize = (20,10))
sns.heatmap(corr_matrix_pps, 
            cmap ='coolwarm', 
            annot = True, 
            linewidths = 1.1,
            square = True)
plt.title("Predictive Power Score(PPS)", fontsize = 12, fontweight = 'bold', color = 'black')
plt.show()

# %%
important_hair = catMap(clean_hair.copy())

y = important_hair['Hair_Loss']  # Target variable
X = important_hair.drop(['Hair_Loss', 'Id'], axis=1)  # Features

# Initialize the Random Forest Classifier
rf_classifier = RandomForestClassifier(n_estimators=100)

# Initialize Stratified K-Fold cross-validation
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores = cross_val_score(rf_classifier, X, y, cv=skf, scoring='accuracy')

# Fit the model to the entire dataset
rf_classifier.fit(X, y)

# Extract feature importance
feature_importance = pd.Series(rf_classifier.feature_importances_, index=X.columns).sort_values(ascending=False)
feature_importance = feature_importance.reset_index()
feature_importance.columns = ['Feature', 'Importance']

# Plotting the bar chart using Seaborn
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='viridis')

# Plot feature importance
plt.title('Feature Importance')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.show()

# %%
bplot_hair = clean_hair.copy().drop('Id', axis=1)

fig, axes = plt.subplots(4, 3, figsize=(15, 20))
axes = axes.flatten()

plt.subplots_adjust(hspace=.5, wspace=1)

# Iterate over variables and plot bar chart for each variable against 'Hair_Loss'
for i, variable in enumerate(bplot_hair.columns):
    if variable == 'Age' or variable == 'Hair_Loss':
        continue
    df_grouped = bplot_hair.groupby([variable, 'Hair_Loss']).size().unstack()
    df_grouped.plot(kind='barh', stacked=False, ax=axes[i], legend=False)
    axes[i].tick_params(axis='both', which='major', labelsize=6)
    axes[i].set_title(f'{variable} and Hair Loss')
    axes[i].set_xlabel('Count')
    axes[i].set_ylabel(variable)
    axes[i].legend(title='Hair Loss', labels=['No Hair Loss', 'Hair Loss'], bbox_to_anchor=(1.05, 1), loc='upper left')
    axes[i].tick_params(axis='x', rotation=0)
    filename = f'{variable}_Hair_Loss_subplot_{i+1}.png'
    axes[i].get_figure().savefig(filename)


axes[6].set_visible(False)
axes[11].set_visible(False)
plt.tight_layout()
plt.show()

# Age, Med & Treatments, Deficiencies, Conditions, Stress

# %%
X = clean_hair.copy().drop(columns = ['Hair_Loss'])
y = clean_hair.copy()['Hair_Loss']

# %%
SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = SEED, stratify = y)

# %%
numerical_predictor = X_train.select_dtypes(include = ['int', 'float']).columns.to_list()
categorical_predictors = X_train.select_dtypes(include = ['object', 'category']).columns.to_list()

# %%
preprocessor = ColumnTransformer([('te', TargetEncoder(min_samples_leaf = 1), categorical_predictors), 
                                  ('kbins', KBinsDiscretizer(n_bins = 10,encode = 'onehot-dense', random_state = SEED), numerical_predictor)], 
                                 remainder = 'passthrough', 
                                 verbose_feature_names_out = False).set_output(transform = 'pandas')

X_train_prep = preprocessor.fit_transform(X_train, y_train)
X_test_prep = preprocessor.transform(X_test)

# %%
lr = LogisticRegression(class_weight = 'balanced', random_state = SEED)
lr.fit(X_train_prep, y_train)

y_pred_train = lr.predict(X_train_prep)
y_pred_test = lr.predict(X_test_prep)

print(f'F2 Train: {fbeta_score(y_train, y_pred_train, beta = 2):.4f}')
print(f'F2 Test: {fbeta_score(y_test, y_pred_test, beta = 2):.4f}')
# Out:
# F2 Train: 0.6163
# F2 Test: 0.4395

# %%
svc = SVC(probability = True, random_state = SEED)
svc.fit(X_train_prep, y_train)

y_pred_train = svc.predict(X_train_prep)
y_pred_test = svc.predict(X_test_prep)

print(f'F2 Train: {fbeta_score(y_train, y_pred_train, beta = 2):.4f}')
print(f'F2 Test: {fbeta_score(y_test, y_pred_test, beta = 2):.4f}')
# Out:
# F2 Train: 0.6894
# F2 Test: 0.4919

# %%
knn = KNeighborsClassifier()
knn.fit(X_train_prep, y_train)

y_pred_train = knn.predict(X_train_prep.values)
y_pred_test = knn.predict(X_test_prep.values)

print(f'F2 Train: {fbeta_score(y_train, y_pred_train, beta = 2):.4f}')
print(f'F2 Test: {fbeta_score(y_test, y_pred_test, beta = 2):.4f}')
# Out:
# F2 Train: 0.7322
# F2 Test: 0.4598
# C:\Users\naran\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\naran\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
